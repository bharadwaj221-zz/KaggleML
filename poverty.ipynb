# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer as DV
from sklearn.feature_selection import *
from sklearn.preprocessing import MinMaxScaler as MMS,LabelEncoder as LE
from sklearn.decomposition import PCA
from sklearn.metrics import *
from sklearn.kernel_ridge import *
from sklearn import tree
from sklearn.ensemble import *
from sklearn.ensemble import *
from sklearn.svm import LinearSVC, SVC, OneClassSVM
from sklearn.model_selection import *
from sklearn.linear_model import *
from collections import defaultdict
from sklearn.neural_network import MLPClassifier
from encoder import Encoder
from imblearn.over_sampling import SMOTE, ADASYN

# %%
df = pd.read_csv('/Users/bjayaram/Documents/Kaggle/poverty/train.csv')
label_cols=df['Target']
cols=df.columns
n=len(cols)
data_cols=cols[:n-1]
label_cols=cols[n-1]
data_cols
# label_cols
# Out:
# Index([u'Id', u'v2a1', u'hacdor', u'rooms', u'hacapo', u'v14a', u'refrig',
#        u'v18q', u'v18q1', u'r4h1',
#        ...
#        u'age', u'SQBescolari', u'SQBage', u'SQBhogar_total', u'SQBedjefe',
#        u'SQBhogar_nin', u'SQBovercrowding', u'SQBdependency', u'SQBmeaned',
#        u'agesq'],
#       dtype='object', length=142)

# %%
y_orig = df[label_cols].values
x_orig = df[data_cols].values
model = LogisticRegressionCV(cv=10, n_jobs=-1, max_iter=500)
model = GridSearchCV(RandomForestClassifier(), cv = 5, n_jobs=-1, param_grid={'n_estimators':range(300,500,50),'class_weight':['balanced']})
model.fit(x_orig,y_orig)
try:
    print "Grid best scores = ",model.best_score_
    print "Grid best param = ",model.best_params_
except:
    print cross_val_score(model,x_train, y_train, scoring='f1', cv=10)
# Out:
# ---------------------------------------------------------------------------
# JoblibValueError                          Traceback (most recent call last)
# <ipython-input-13-066f740c80bc> in <module>()
#       3 model = LogisticRegressionCV(cv=10, n_jobs=-1, max_iter=500)
#       4 model = GridSearchCV(RandomForestClassifier(), cv = 5, n_jobs=-1, param_grid={'n_estimators':range(300,500,50),'class_weight':['balanced']})
# ----> 5 model.fit(x_orig,y_orig)
#       6 try:
#       7     print "Grid best scores = ",model.best_score_
#
# /Users/bjayaram/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in fit(self, X, y, groups, **fit_params)
#     636                                   error_score=self.error_score)
#     637           for parameters, (train, test) in product(candidate_params,
# --> 638                                                    cv.split(X, y, groups)))
#     639
# ...
